# %% [markdown]
# # Kipoi python API

# %% [markdown]
# ## Quick start

# %% [markdown]
# There are three basic building blocks in kipoi:
#
# - **Source** - provides Models and DataLoaders.
# - **Model** - makes the prediction given the numpy arrays.
# - **Dataloader** - loads the data from raw files and transforms them into a form that is directly consumable by the Model

# %% [markdown]
# ![img](../docs/theme_dir/img/kipoi-workflow.png)

# %% [markdown]
# ## List of main commands
#
#
# - `kipoi.list_sources()`
# - `kipoi.get_source()`
#
#
# - `kipoi.list_models()`
# - `kipoi.list_dataloaders()`
#
#
# - `kipoi.get_model()`
# - `kipoi.get_dataloader_factory()`

# %% [markdown]
# ### Source
#
# Available sources are specified in the config file located at: `~/.kipoi/config.yaml`. Here is an example config file:
#
# ```yaml
# model_sources:
#     kipoi: # default
#         type: git-lfs # git repository with large file storage (git-lfs)
#         remote_url: git@github.com:kipoi/models.git # git remote
#         local_path: ~/.kipoi/models/ # local storage path
#     gl:
#         type: git-lfs  # custom model
#         remote_url: https://i12g-gagneurweb.informatik.tu-muenchen.de/gitlab/gagneurlab/model-zoo.git
#         local_path: /s/project/model-zoo
# ```
#
# There are three different model sources possible:
#
# - **`git-lfs`** - git repository with source files tracked normally by git and all the binary files like model weights (located in `files*` directories) are tracked by [git-lfs](https://git-lfs.github.com).
#   - Requires `git-lfs` to be installed.
# - **`git`** - all the files including weights (not recommended)
# - **`local`** - local directory containing models defined in subdirectories
#
# For **`git-lfs`** source type, larger files tracked by `git-lfs` will be downloaded into the specified directory `local_path` only after the model has been requested (when invoking `kipoi.get_model()`).
#
# #### Note
#
# A particular model/dataloader is defined by its source (say `kipoi` or `my_git_models`) and the relative path of the desired model directory from the model source root (say `rbp/`).
#
# A directory is considered a model if it contains a `model.yaml` file.

# %%
import kipoi

# %%
import warnings
warnings.filterwarnings('ignore')

import logging
logging.disable(1000)

# %%
kipoi.list_sources()
# Out:
#   source     type                        location local_size  n_models  \
# 0  kipoi  git-lfs  /homes/rkreuzhu/.kipoi/models/       5.0G       780
#
#    n_dataloaders
# 0            780

# %%
s = kipoi.get_source("kipoi")

# %%
s
# Out:
# GitLFSSource(remote_url='git@github.com:kipoi/models.git', local_path='/homes/rkreuzhu/.kipoi/models/')

# %%
kipoi.list_models()
# Out:
#     source                                model version  \
# 0    kipoi             CpGenie/A549_ENCSR000DDI     0.1
# 1    kipoi             CpGenie/BE2C_ENCSR000DEB     0.1
# 2    kipoi               CpGenie/BJ_ENCSR000DEA     0.1
# 3    kipoi              CpGenie/CMK_ENCSR000DGJ     0.1
# 4    kipoi           CpGenie/Caco_2_ENCSR000DDO     0.1
# 5    kipoi          CpGenie/GM06990_ENCSR000DDN     0.1
# 6    kipoi          CpGenie/GM12878_ENCSR000DEY     0.1
# 7    kipoi          CpGenie/GM12878_ENCSR000DFT     0.1
# 8    kipoi          CpGenie/GM12891_ENCSR000DFO     0.1
# 9    kipoi          CpGenie/GM12892_ENCSR000DFN     0.1
# 10   kipoi          CpGenie/GM19239_ENCSR000DGH     0.1
# 11   kipoi          CpGenie/GM19240_ENCSR000DGG     0.1
# 12   kipoi           CpGenie/HCT116_ENCSR000DFS     0.1
# 13   kipoi           CpGenie/HEK293_ENCSR087IEW     0.1
# 14   kipoi           CpGenie/HEK293_ENCSR794HFF     0.1
# 15   kipoi        CpGenie/HGPS_cell_ENCSR000DFA     0.1
# 16   kipoi            CpGenie/HL_60_ENCSR000DDM     0.1
# 17   kipoi      CpGenie/HTR_8_SVneo_ENCSR000DDP     0.1
# 18   kipoi          CpGenie/HeLa_S3_ENCSR000DFL     0.1
# 19   kipoi            CpGenie/HepG2_ENCSR530RCY     0.1
# 20   kipoi            CpGenie/HepG2_ENCSR592WWM     0.1
# 21   kipoi           CpGenie/IMR_90_ENCSR000DEX     0.1
# 22   kipoi         CpGenie/Ishikawa_ENCSR000DDZ     0.1
# 23   kipoi           CpGenie/Jurkat_ENCSR000DFP     0.1
# 24   kipoi             CpGenie/K562_ENCSR000DFK     0.1
# 25   kipoi  CpGenie/LNCaP_clone_FGC_ENCSR000DFH     0.1
# 26   kipoi  CpGenie/LNCaP_clone_FGC_ENCSR439FXM     0.1
# 27   kipoi  CpGenie/LNCaP_clone_FGC_ENCSR859PDD     0.1
# 28   kipoi          CpGenie/MCF_10A_ENCSR000DEV     0.1
# 29   kipoi          CpGenie/MCF_10A_ENCSR000DEW     0.1
# ..     ...                                  ...     ...
# 753  kipoi   tf-binding/human/pwm/HOCOMOCO/ZEP1     0.1
# 754  kipoi   tf-binding/human/pwm/HOCOMOCO/ZEP2     0.1
# 755  kipoi  tf-binding/human/pwm/HOCOMOCO/ZFHX3     0.1
# 756  kipoi    tf-binding/human/pwm/HOCOMOCO/ZFX     0.1
# 757  kipoi   tf-binding/human/pwm/HOCOMOCO/ZIC1     0.1
# 758  kipoi   tf-binding/human/pwm/HOCOMOCO/ZIC2     0.1
# 759  kipoi   tf-binding/human/pwm/HOCOMOCO/ZIC3     0.1
# 760  kipoi   tf-binding/human/pwm/HOCOMOCO/ZIC4     0.1
# 761  kipoi  tf-binding/human/pwm/HOCOMOCO/ZKSC1     0.1
# 762  kipoi  tf-binding/human/pwm/HOCOMOCO/ZKSC3     0.1
# 763  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN143     0.1
# 764  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN148     0.1
# 765  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN219     0.1
# 766  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN232     0.1
# 767  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN282     0.1
# 768  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN333     0.1
# 769  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN350     0.1
# 770  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN384     0.1
# 771  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN410     0.1
# 772  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN423     0.1
# 773  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN524     0.1
# 774  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN589     0.1
# 775  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN639     0.1
# 776  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN652     0.1
# 777  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN713     0.1
# 778  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN740     0.1
# 779  kipoi  tf-binding/human/pwm/HOCOMOCO/ZN784     0.1
# 780  kipoi  tf-binding/human/pwm/HOCOMOCO/ZSC16     0.1
# 781  kipoi  tf-binding/human/pwm/HOCOMOCO/ZSCA4     0.1
# 783  kipoi                   BassetGM12878_Demo     0.1
#
#                                                authors  \
# 0    [Author(name='Haoyang Zeng', github='haoyangz'...
# 1    [Author(name='Haoyang Zeng', github='haoyangz'...
# 2    [Author(name='Haoyang Zeng', github='haoyangz'...
# 3    [Author(name='Haoyang Zeng', github='haoyangz'...
# 4    [Author(name='Haoyang Zeng', github='haoyangz'...
# 5    [Author(name='Haoyang Zeng', github='haoyangz'...
# 6    [Author(name='Haoyang Zeng', github='haoyangz'...
# 7    [Author(name='Haoyang Zeng', github='haoyangz'...
# 8    [Author(name='Haoyang Zeng', github='haoyangz'...
# 9    [Author(name='Haoyang Zeng', github='haoyangz'...
# 10   [Author(name='Haoyang Zeng', github='haoyangz'...
# 11   [Author(name='Haoyang Zeng', github='haoyangz'...
# 12   [Author(name='Haoyang Zeng', github='haoyangz'...
# 13   [Author(name='Haoyang Zeng', github='haoyangz'...
# 14   [Author(name='Haoyang Zeng', github='haoyangz'...
# 15   [Author(name='Haoyang Zeng', github='haoyangz'...
# 16   [Author(name='Haoyang Zeng', github='haoyangz'...
# 17   [Author(name='Haoyang Zeng', github='haoyangz'...
# 18   [Author(name='Haoyang Zeng', github='haoyangz'...
# 19   [Author(name='Haoyang Zeng', github='haoyangz'...
# 20   [Author(name='Haoyang Zeng', github='haoyangz'...
# 21   [Author(name='Haoyang Zeng', github='haoyangz'...
# 22   [Author(name='Haoyang Zeng', github='haoyangz'...
# 23   [Author(name='Haoyang Zeng', github='haoyangz'...
# 24   [Author(name='Haoyang Zeng', github='haoyangz'...
# 25   [Author(name='Haoyang Zeng', github='haoyangz'...
# 26   [Author(name='Haoyang Zeng', github='haoyangz'...
# 27   [Author(name='Haoyang Zeng', github='haoyangz'...
# 28   [Author(name='Haoyang Zeng', github='haoyangz'...
# 29   [Author(name='Haoyang Zeng', github='haoyangz'...
# ..                                                 ...
# 753  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 754  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 755  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 756  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 757  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 758  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 759  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 760  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 761  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 762  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 763  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 764  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 765  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 766  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 767  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 768  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 769  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 770  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 771  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 772  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 773  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 774  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 775  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 776  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 777  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 778  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 779  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 780  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 781  [Author(name='Ivan V. Kulakovskiy', github=Non...
# 783  [Author(name='Nancy Xu', github='xnancy', emai...
#
#                                           contributors  \
# 0    [Author(name='Roman Kreuzhuber', github='krrom...
# 1    [Author(name='Roman Kreuzhuber', github='krrom...
# 2    [Author(name='Roman Kreuzhuber', github='krrom...
# 3    [Author(name='Roman Kreuzhuber', github='krrom...
# 4    [Author(name='Roman Kreuzhuber', github='krrom...
# 5    [Author(name='Roman Kreuzhuber', github='krrom...
# 6    [Author(name='Roman Kreuzhuber', github='krrom...
# 7    [Author(name='Roman Kreuzhuber', github='krrom...
# 8    [Author(name='Roman Kreuzhuber', github='krrom...
# 9    [Author(name='Roman Kreuzhuber', github='krrom...
# 10   [Author(name='Roman Kreuzhuber', github='krrom...
# 11   [Author(name='Roman Kreuzhuber', github='krrom...
# 12   [Author(name='Roman Kreuzhuber', github='krrom...
# 13   [Author(name='Roman Kreuzhuber', github='krrom...
# 14   [Author(name='Roman Kreuzhuber', github='krrom...
# 15   [Author(name='Roman Kreuzhuber', github='krrom...
# 16   [Author(name='Roman Kreuzhuber', github='krrom...
# 17   [Author(name='Roman Kreuzhuber', github='krrom...
# 18   [Author(name='Roman Kreuzhuber', github='krrom...
# 19   [Author(name='Roman Kreuzhuber', github='krrom...
# 20   [Author(name='Roman Kreuzhuber', github='krrom...
# 21   [Author(name='Roman Kreuzhuber', github='krrom...
# 22   [Author(name='Roman Kreuzhuber', github='krrom...
# 23   [Author(name='Roman Kreuzhuber', github='krrom...
# 24   [Author(name='Roman Kreuzhuber', github='krrom...
# 25   [Author(name='Roman Kreuzhuber', github='krrom...
# 26   [Author(name='Roman Kreuzhuber', github='krrom...
# 27   [Author(name='Roman Kreuzhuber', github='krrom...
# 28   [Author(name='Roman Kreuzhuber', github='krrom...
# 29   [Author(name='Roman Kreuzhuber', github='krrom...
# ..                                                 ...
# 753  [Author(name='Ziga Avsec', github='avsecz', em...
# 754  [Author(name='Ziga Avsec', github='avsecz', em...
# 755  [Author(name='Ziga Avsec', github='avsecz', em...
# 756  [Author(name='Ziga Avsec', github='avsecz', em...
# 757  [Author(name='Ziga Avsec', github='avsecz', em...
# 758  [Author(name='Ziga Avsec', github='avsecz', em...
# 759  [Author(name='Ziga Avsec', github='avsecz', em...
# 760  [Author(name='Ziga Avsec', github='avsecz', em...
# 761  [Author(name='Ziga Avsec', github='avsecz', em...
# 762  [Author(name='Ziga Avsec', github='avsecz', em...
# 763  [Author(name='Ziga Avsec', github='avsecz', em...
# 764  [Author(name='Ziga Avsec', github='avsecz', em...
# 765  [Author(name='Ziga Avsec', github='avsecz', em...
# 766  [Author(name='Ziga Avsec', github='avsecz', em...
# 767  [Author(name='Ziga Avsec', github='avsecz', em...
# 768  [Author(name='Ziga Avsec', github='avsecz', em...
# 769  [Author(name='Ziga Avsec', github='avsecz', em...
# 770  [Author(name='Ziga Avsec', github='avsecz', em...
# 771  [Author(name='Ziga Avsec', github='avsecz', em...
# 772  [Author(name='Ziga Avsec', github='avsecz', em...
# 773  [Author(name='Ziga Avsec', github='avsecz', em...
# 774  [Author(name='Ziga Avsec', github='avsecz', em...
# 775  [Author(name='Ziga Avsec', github='avsecz', em...
# 776  [Author(name='Ziga Avsec', github='avsecz', em...
# 777  [Author(name='Ziga Avsec', github='avsecz', em...
# 778  [Author(name='Ziga Avsec', github='avsecz', em...
# 779  [Author(name='Ziga Avsec', github='avsecz', em...
# 780  [Author(name='Ziga Avsec', github='avsecz', em...
# 781  [Author(name='Ziga Avsec', github='avsecz', em...
# 783  [Author(name='Nancy Xu', github='xnancy', emai...
#
#                                                    doc   type  \
# 0    Abstract: DNA methylation plays a crucial role...  keras
# 1    Abstract: DNA methylation plays a crucial role...  keras
# 2    Abstract: DNA methylation plays a crucial role...  keras
# 3    Abstract: DNA methylation plays a crucial role...  keras
# 4    Abstract: DNA methylation plays a crucial role...  keras
# 5    Abstract: DNA methylation plays a crucial role...  keras
# 6    Abstract: DNA methylation plays a crucial role...  keras
# 7    Abstract: DNA methylation plays a crucial role...  keras
# 8    Abstract: DNA methylation plays a crucial role...  keras
# 9    Abstract: DNA methylation plays a crucial role...  keras
# 10   Abstract: DNA methylation plays a crucial role...  keras
# 11   Abstract: DNA methylation plays a crucial role...  keras
# 12   Abstract: DNA methylation plays a crucial role...  keras
# 13   Abstract: DNA methylation plays a crucial role...  keras
# 14   Abstract: DNA methylation plays a crucial role...  keras
# 15   Abstract: DNA methylation plays a crucial role...  keras
# 16   Abstract: DNA methylation plays a crucial role...  keras
# 17   Abstract: DNA methylation plays a crucial role...  keras
# 18   Abstract: DNA methylation plays a crucial role...  keras
# 19   Abstract: DNA methylation plays a crucial role...  keras
# 20   Abstract: DNA methylation plays a crucial role...  keras
# 21   Abstract: DNA methylation plays a crucial role...  keras
# 22   Abstract: DNA methylation plays a crucial role...  keras
# 23   Abstract: DNA methylation plays a crucial role...  keras
# 24   Abstract: DNA methylation plays a crucial role...  keras
# 25   Abstract: DNA methylation plays a crucial role...  keras
# 26   Abstract: DNA methylation plays a crucial role...  keras
# 27   Abstract: DNA methylation plays a crucial role...  keras
# 28   Abstract: DNA methylation plays a crucial role...  keras
# 29   Abstract: DNA methylation plays a crucial role...  keras
# ..                                                 ...    ...
# 753  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 754  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 755  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 756  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 757  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 758  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 759  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 760  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 761  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 762  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 763  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 764  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 765  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 766  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 767  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 768  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 769  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 770  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 771  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 772  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 773  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 774  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 775  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 776  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 777  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 778  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 779  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 780  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 781  '''Simple PWM-scanning model\nPWM database: HO...  keras
# 783                                               test  keras
#
#                      inputs           targets  postproc_score_variants  \
# 0                       seq  methylation_prob                     True
# 1                       seq  methylation_prob                     True
# 2                       seq  methylation_prob                     True
# 3                       seq  methylation_prob                     True
# 4                       seq  methylation_prob                     True
# 5                       seq  methylation_prob                     True
# 6                       seq  methylation_prob                     True
# 7                       seq  methylation_prob                     True
# 8                       seq  methylation_prob                     True
# 9                       seq  methylation_prob                     True
# 10                      seq  methylation_prob                     True
# 11                      seq  methylation_prob                     True
# 12                      seq  methylation_prob                     True
# 13                      seq  methylation_prob                     True
# 14                      seq  methylation_prob                     True
# 15                      seq  methylation_prob                     True
# 16                      seq  methylation_prob                     True
# 17                      seq  methylation_prob                     True
# 18                      seq  methylation_prob                     True
# 19                      seq  methylation_prob                     True
# 20                      seq  methylation_prob                     True
# 21                      seq  methylation_prob                     True
# 22                      seq  methylation_prob                     True
# 23                      seq  methylation_prob                     True
# 24                      seq  methylation_prob                     True
# 25                      seq  methylation_prob                     True
# 26                      seq  methylation_prob                     True
# 27                      seq  methylation_prob                     True
# 28                      seq  methylation_prob                     True
# 29                      seq  methylation_prob                     True
# ..                      ...               ...                      ...
# 753                     seq         pwm_match                     True
# 754                     seq         pwm_match                     True
# 755                     seq         pwm_match                     True
# 756                     seq         pwm_match                     True
# 757                     seq         pwm_match                     True
# 758                     seq         pwm_match                     True
# 759                     seq         pwm_match                     True
# 760                     seq         pwm_match                     True
# 761                     seq         pwm_match                     True
# 762                     seq         pwm_match                     True
# 763                     seq         pwm_match                     True
# 764                     seq         pwm_match                     True
# 765                     seq         pwm_match                     True
# 766                     seq         pwm_match                     True
# 767                     seq         pwm_match                     True
# 768                     seq         pwm_match                     True
# 769                     seq         pwm_match                     True
# 770                     seq         pwm_match                     True
# 771                     seq         pwm_match                     True
# 772                     seq         pwm_match                     True
# 773                     seq         pwm_match                     True
# 774                     seq         pwm_match                     True
# 775                     seq         pwm_match                     True
# 776                     seq         pwm_match                     True
# 777                     seq         pwm_match                     True
# 778                     seq         pwm_match                     True
# 779                     seq         pwm_match                     True
# 780                     seq         pwm_match                     True
# 781                     seq         pwm_match                     True
# 783  [data/genome_data_dir]              None                    False
#
#                license                             cite_as  \
# 0    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 1    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 2    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 3    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 4    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 5    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 6    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 7    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 8    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 9    Apache License v2  https://doi.org/10.1093/nar/gkx177
# 10   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 11   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 12   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 13   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 14   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 15   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 16   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 17   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 18   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 19   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 20   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 21   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 22   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 23   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 24   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 25   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 26   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 27   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 28   Apache License v2  https://doi.org/10.1093/nar/gkx177
# 29   Apache License v2  https://doi.org/10.1093/nar/gkx177
# ..                 ...                                 ...
# 753                MIT     https://doi:10.1093/nar/gkv1249
# 754                MIT     https://doi:10.1093/nar/gkv1249
# 755                MIT     https://doi:10.1093/nar/gkv1249
# 756                MIT     https://doi:10.1093/nar/gkv1249
# 757                MIT     https://doi:10.1093/nar/gkv1249
# 758                MIT     https://doi:10.1093/nar/gkv1249
# 759                MIT     https://doi:10.1093/nar/gkv1249
# 760                MIT     https://doi:10.1093/nar/gkv1249
# 761                MIT     https://doi:10.1093/nar/gkv1249
# 762                MIT     https://doi:10.1093/nar/gkv1249
# 763                MIT     https://doi:10.1093/nar/gkv1249
# 764                MIT     https://doi:10.1093/nar/gkv1249
# 765                MIT     https://doi:10.1093/nar/gkv1249
# 766                MIT     https://doi:10.1093/nar/gkv1249
# 767                MIT     https://doi:10.1093/nar/gkv1249
# 768                MIT     https://doi:10.1093/nar/gkv1249
# 769                MIT     https://doi:10.1093/nar/gkv1249
# 770                MIT     https://doi:10.1093/nar/gkv1249
# 771                MIT     https://doi:10.1093/nar/gkv1249
# 772                MIT     https://doi:10.1093/nar/gkv1249
# 773                MIT     https://doi:10.1093/nar/gkv1249
# 774                MIT     https://doi:10.1093/nar/gkv1249
# 775                MIT     https://doi:10.1093/nar/gkv1249
# 776                MIT     https://doi:10.1093/nar/gkv1249
# 777                MIT     https://doi:10.1093/nar/gkv1249
# 778                MIT     https://doi:10.1093/nar/gkv1249
# 779                MIT     https://doi:10.1093/nar/gkv1249
# 780                MIT     https://doi:10.1093/nar/gkv1249
# 781                MIT     https://doi:10.1093/nar/gkv1249
# 783                MIT                                None
#
#                                             trained_on training_procedure  \
# 0    RRBS (restricted representation bisulfite sequ...            RMSprop
# 1    RRBS (restricted representation bisulfite sequ...            RMSprop
# 2    RRBS (restricted representation bisulfite sequ...            RMSprop
# 3    RRBS (restricted representation bisulfite sequ...            RMSprop
# 4    RRBS (restricted representation bisulfite sequ...            RMSprop
# 5    RRBS (restricted representation bisulfite sequ...            RMSprop
# 6    RRBS (restricted representation bisulfite sequ...            RMSprop
# 7    RRBS (restricted representation bisulfite sequ...            RMSprop
# 8    RRBS (restricted representation bisulfite sequ...            RMSprop
# 9    RRBS (restricted representation bisulfite sequ...            RMSprop
# 10   RRBS (restricted representation bisulfite sequ...            RMSprop
# 11   RRBS (restricted representation bisulfite sequ...            RMSprop
# 12   RRBS (restricted representation bisulfite sequ...            RMSprop
# 13   RRBS (restricted representation bisulfite sequ...            RMSprop
# 14   RRBS (restricted representation bisulfite sequ...            RMSprop
# 15   RRBS (restricted representation bisulfite sequ...            RMSprop
# 16   RRBS (restricted representation bisulfite sequ...            RMSprop
# 17   RRBS (restricted representation bisulfite sequ...            RMSprop
# 18   RRBS (restricted representation bisulfite sequ...            RMSprop
# 19   RRBS (restricted representation bisulfite sequ...            RMSprop
# 20   RRBS (restricted representation bisulfite sequ...            RMSprop
# 21   RRBS (restricted representation bisulfite sequ...            RMSprop
# 22   RRBS (restricted representation bisulfite sequ...            RMSprop
# 23   RRBS (restricted representation bisulfite sequ...            RMSprop
# 24   RRBS (restricted representation bisulfite sequ...            RMSprop
# 25   RRBS (restricted representation bisulfite sequ...            RMSprop
# 26   RRBS (restricted representation bisulfite sequ...            RMSprop
# 27   RRBS (restricted representation bisulfite sequ...            RMSprop
# 28   RRBS (restricted representation bisulfite sequ...            RMSprop
# 29   RRBS (restricted representation bisulfite sequ...            RMSprop
# ..                                                 ...                ...
# 753                                               None               None
# 754                                               None               None
# 755                                               None               None
# 756                                               None               None
# 757                                               None               None
# 758                                               None               None
# 759                                               None               None
# 760                                               None               None
# 761                                               None               None
# 762                                               None               None
# 763                                               None               None
# 764                                               None               None
# 765                                               None               None
# 766                                               None               None
# 767                                               None               None
# 768                                               None               None
# 769                                               None               None
# 770                                               None               None
# 771                                               None               None
# 772                                               None               None
# 773                                               None               None
# 774                                               None               None
# 775                                               None               None
# 776                                               None               None
# 777                                               None               None
# 778                                               None               None
# 779                                               None               None
# 780                                               None               None
# 781                                               None               None
# 783                                               None               None
#
#                     tags
# 0      [DNA methylation]
# 1      [DNA methylation]
# 2      [DNA methylation]
# 3      [DNA methylation]
# 4      [DNA methylation]
# 5      [DNA methylation]
# 6      [DNA methylation]
# 7      [DNA methylation]
# 8      [DNA methylation]
# 9      [DNA methylation]
# 10     [DNA methylation]
# 11     [DNA methylation]
# 12     [DNA methylation]
# 13     [DNA methylation]
# 14     [DNA methylation]
# 15     [DNA methylation]
# 16     [DNA methylation]
# 17     [DNA methylation]
# 18     [DNA methylation]
# 19     [DNA methylation]
# 20     [DNA methylation]
# 21     [DNA methylation]
# 22     [DNA methylation]
# 23     [DNA methylation]
# 24     [DNA methylation]
# 25     [DNA methylation]
# 26     [DNA methylation]
# 27     [DNA methylation]
# 28     [DNA methylation]
# 29     [DNA methylation]
# ..                   ...
# 753        [DNA binding]
# 754        [DNA binding]
# 755        [DNA binding]
# 756        [DNA binding]
# 757        [DNA binding]
# 758        [DNA binding]
# 759        [DNA binding]
# 760        [DNA binding]
# 761        [DNA binding]
# 762        [DNA binding]
# 763        [DNA binding]
# 764        [DNA binding]
# 765        [DNA binding]
# 766        [DNA binding]
# 767        [DNA binding]
# 768        [DNA binding]
# 769        [DNA binding]
# 770        [DNA binding]
# 771        [DNA binding]
# 772        [DNA binding]
# 773        [DNA binding]
# 774        [DNA binding]
# 775        [DNA binding]
# 776        [DNA binding]
# 777        [DNA binding]
# 778        [DNA binding]
# 779        [DNA binding]
# 780        [DNA binding]
# 781        [DNA binding]
# 783  [DNA accessibility]
#
# [780 rows x 15 columns]

# %% [markdown]
# ## Model
#
# Let's choose to use the `rbp_eclip/UPF1` model from kipoi

# %%
# Note. Install all the dependencies for that model using
# kipoi env install 
model = kipoi.get_model("rbp_eclip/UPF1")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Available fields:
#
# #### Model
#
# - type
# - args
# - info
#   - authors
#   - name
#   - version
#   - tags
#   - doc
# - schema
#   - inputs
#   - targets
# - default_dataloader - loaded dataloader class
#
#
# - predict_on_batch()
# - source
# - source_dir
# - pipeline
#   - predict()
#   - predict_example()
#   - predict_generator()
#
# #### Dataloader
#
# - type
# - defined_as
# - args
# - info (same as for the model)
# - output_schema
#   - inputs
#   - targets
#   - metadata
#
#
# - source
# - source_dir
# - example_kwargs
# - init_example()
# - batch_iter()
# - batch_train_iter()
# - batch_predict_iter()
# - load_all()

# %%
model

# %%
model.type
# Out:
# 'keras'

# %% [markdown]
# ### Info

# %%
model.info
# Out:
# ModelInfo(authors=[Author(name='Ziga Avsec', github='avsecz', email=None)], doc='\'RBP binding model from Avsec et al: "Modeling positional effects of regulatory sequences with spline transformations increases prediction accuracy of deep neural networks". \'\n', name=None, version='0.1', license='MIT', tags=['RNA binding'], contributors=[Author(name='Ziga Avsec', github='avsecz', email=None)], cite_as='https://doi.org/10.1093/bioinformatics/btx727', trained_on='RBP occupancy peaks measured by eCLIP-seq (Van Nostrand et al., 2016 - https://doi.org/10.1038/nmeth.3810), https://github.com/gagneurlab/Manuscript_Avsec_Bioinformatics_2017\n', training_procedure='Single task training with ADAM')

# %%
model.info.version
# Out:
# '0.1'

# %% [markdown]
# ### Schema

# %%
dict(model.schema.inputs)
# Out:
# {'dist_exon_intron': ArraySchema(shape=(1, 10), doc='Distance the nearest exon_intron (splice donor) site transformed with B-splines', name='dist_exon_intron', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_gene_end': ArraySchema(shape=(1, 10), doc='Distance the nearest gene end transformed with B-splines', name='dist_gene_end', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_gene_start': ArraySchema(shape=(1, 10), doc='Distance the nearest gene start transformed with B-splines', name='dist_gene_start', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_intron_exon': ArraySchema(shape=(1, 10), doc='Distance the nearest intron_exon (splice acceptor) site transformed with B-splines', name='dist_intron_exon', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_polya': ArraySchema(shape=(1, 10), doc='Distance the nearest Poly-A site transformed with B-splines', name='dist_polya', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_start_codon': ArraySchema(shape=(1, 10), doc='Distance the nearest start codon transformed with B-splines', name='dist_start_codon', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_stop_codon': ArraySchema(shape=(1, 10), doc='Distance the nearest stop codon transformed with B-splines', name='dist_stop_codon', special_type=None, associated_metadata=[], column_labels=None),
#  'dist_tss': ArraySchema(shape=(1, 10), doc='Distance the nearest TSS site transformed with B-splines', name='dist_tss', special_type=None, associated_metadata=[], column_labels=None),
#  'seq': ArraySchema(shape=(101, 4), doc='One-hot encoded RNA sequence', name='seq', special_type=<ArraySpecialType.DNASeq: 'DNASeq'>, associated_metadata=[], column_labels=None)}

# %%
model.schema.targets
# Out:
# ArraySchema(shape=(1,), doc='Predicted binding strength', name=None, special_type=None, associated_metadata=[], column_labels=None)

# %% [markdown]
# ### Default dataloader
#
# Model already has the default dataloder present. To use it, specify

# %%
model.source_dir
# Out:
# '/homes/rkreuzhu/.kipoi/models/rbp_eclip/UPF1'

# %%
model.default_dataloader
# Out:
# dataloader.SeqDistDataset

# %%
model.default_dataloader.info
# Out:
# Info(authors=[Author(name='Ziga Avsec', github='avsecz', email=None)], doc='RBP binding model taking as input 101nt long sequence as well as 8 distances to nearest genomic landmarks -  tss, poly-A, exon-intron boundary, intron-exon boundary, start codon, stop codon, gene start, gene end\n', name=None, version='0.1', license='MIT', tags=[])

# %% [markdown]
# ### Predict_on_batch

# %%
model.predict_on_batch
# Out:
# <bound method KerasModel.predict_on_batch of <kipoi.model.KerasModel object at 0x2ada1ede6cc0>>

# %% [markdown]
# ### Pipeline
#
# Pipeline object will take the dataloader arguments and run the whole pipeline:
#
# ```
# dataloader arguments --Dataloader-->  numpy arrays --Model--> prediction
# ```

# %%
#model.pipeline.predict

# %%
#model.pipeline.predict_generator

# %% [markdown]
# ### Others

# %%
# Model source
model.source
# Out:
# GitLFSSource(remote_url='git@github.com:kipoi/models.git', local_path='/homes/rkreuzhu/.kipoi/models/')

# %%
# model location directory
model.source_dir
# Out:
# '/homes/rkreuzhu/.kipoi/models/rbp_eclip/UPF1'

# %% [markdown]
# ## DataLoader

# %%
DataLoader = kipoi.get_dataloader_factory("rbp_eclip/UPF1")

# %% [markdown]
# A dataloader will most likely require input arguments in which the input files are defined, for example input fasta files or bed files, based on which the model input is generated. There are several options where the dataloader input keyword arguments are displayed:

# %%
# Display information about the dataloader
print(DataLoader.__doc__)
# Out:
#     Args:
#         intervals_file: file path; tsv file
#             Assumes bed-like `chrom start end id score strand` format.
#         fasta_file: file path; Genome sequence
#         gtf_file: file path; Genome annotation GTF file.
#         filter_protein_coding: Considering genomic landmarks only for protein coding genes
#         preproc_transformer: file path; tranformer used for pre-processing.
#         target_file: file path; path to the targets
#         batch_size: int

# %%
# Alternatively the dataloader keyword arguments can be displayed using the function:
kipoi.print_dl_kwargs(DataLoader)
# Out:
# Keyword argument: `intervals_file`
#     doc: bed6 file with `chrom start end id score strand` columns
#     type: str
#     optional: False
#     example: example_files/intervals.bed
# Keyword argument: `fasta_file`
#     doc: Reference genome sequence
#     type: str
#     optional: False
#     example: example_files/hg38_chr22.fa
# Keyword argument: `gtf_file`
#     doc: file path; Genome annotation GTF file
#     type: str
#     optional: False
#     example: example_files/gencode.v24.annotation_chr22.gtf
# Keyword argument: `filter_protein_coding`
#     doc: Considering genomic landmarks only for protein coding genes when computing the distances to the nearest genomic landmark.
#     type: str
#     optional: True
#     example: True
# Keyword argument: `target_file`
#     doc: path to the targets (txt) file
#     type: str
#     optional: True
#     example: example_files/targets.tsv
# Keyword argument: `use_linecache`
#     doc: if True, use linecache https://docs.python.org/3/library/linecache.html to access bed file rows
#     type: str
#     optional: True
# --------------------------------------------------------------------------------
# Example keyword arguments are: {'gtf_file': 'example_files/gencode.v24.annotation_chr22.gtf', 'fasta_file': 'example_files/hg38_chr22.fa', 'target_file': 'example_files/targets.tsv', 'intervals_file': 'example_files/intervals.bed', 'filter_protein_coding': True}

# %% [markdown]
# ## Run dataloader on some examples

# %%
# each dataloader already provides example files which can be used to illustrate its use:
DataLoader.example_kwargs
# Out:
# {'fasta_file': 'example_files/hg38_chr22.fa',
#  'filter_protein_coding': True,
#  'gtf_file': 'example_files/gencode.v24.annotation_chr22.gtf',
#  'intervals_file': 'example_files/intervals.bed',
#  'target_file': 'example_files/targets.tsv'}

# %%
import os

# %%
# cd into the source directory 
os.chdir(DataLoader.source_dir)

# %%
# !tree
# Out:
# .
# ├── custom_keras_objects.py -> ../template/custom_keras_objects.py
# ├── dataloader_files
# │   └── position_transformer.pkl
# ├── dataloader.py -> ../template/dataloader.py
# ├── dataloader.yaml -> ../template/dataloader.yaml
# ├── example_files -> ../template/example_files
# ├── model_files
# │   └── model.h5
# ├── model.yaml -> ../template/model.yaml
# └── __pycache__
#     ├── custom_keras_objects.cpython-35.pyc
#     └── dataloader.cpython-35.pyc
#
# 4 directories, 8 files

# %%
dl = DataLoader(**DataLoader.example_kwargs)
# could be also done with DataLoader.init_example()

# %%
# This particular dataloader is of type Dataset
# i.e. it implements the __getitem__ method:
dl[0].keys()
# Out:
# dict_keys(['metadata', 'inputs', 'targets'])

# %%
dl[0]["inputs"].keys()
# Out:
# dict_keys(['dist_gene_start', 'dist_gene_end', 'dist_stop_codon', 'dist_exon_intron', 'dist_start_codon', 'dist_tss', 'seq', 'dist_polya', 'dist_intron_exon'])

# %%
dl[0]["inputs"]["seq"][:5]
# Out:
# array([[0.25, 0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25, 0.25]], dtype=float32)

# %%
len(dl)
# Out:
# 14

# %% [markdown]
# ### Get the whole dataset

# %%
whole_data = dl.load_all()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]

# %%
whole_data.keys()
# Out:
# dict_keys(['metadata', 'inputs', 'targets'])

# %%
whole_data["inputs"]["seq"].shape
# Out:
# (14, 101, 4)

# %% [markdown]
# ### Get the iterator to run predictions

# %%
it = dl.batch_iter(batch_size=1, shuffle=False, num_workers=0, drop_last=False)

# %%
next(it)["inputs"]["seq"].shape
# Out:
# (1, 101, 4)

# %%
model.predict_on_batch(next(it)["inputs"])
# Out:
# array([[0.00050414]], dtype=float32)

# %% [markdown]
# ### Train the Keras model
#
# Keras model is stored under the `.model` attribute.

# %%
model.model.compile("adam", "binary_crossentropy")

# %%
train_it = dl.batch_train_iter(batch_size=2)

# %%
# model.model.summary()

# %%
model.model.fit_generator(train_it, steps_per_epoch=3, epochs=1)
# Out:
# Epoch 1/1
# 3/3 [==============================] - 1s 270ms/step - loss: 1.0971

# %% [markdown]
# ## Pipeline: `raw files -[dataloader]-> numpy arrays -[model]-> prediction`

# %%
example_kwargs = model.default_dataloader.example_kwargs

# %%
model.pipeline.predict(example_kwargs)
# Out:
# 1it [00:02,  2.67s/it]
# array([1.        , 0.52299094, 0.52299094, 1.        , 1.        ,
#        1.        , 0.52299094, 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.        ], dtype=float32)

# %%
next(model.pipeline.predict_generator(example_kwargs, batch_size=2))
# Out:
# array([[1.        ],
#        [0.52299076]], dtype=float32)
